# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir("C:/Users/Arunita.000/Desktop/20-fifa_data.csv")
data=pd.read_csv("data.csv")

# %%
#to read all coloumn headings and view initial 5 data
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
#to read all the coloumn names
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
#to get the total number of rows and columns
data.shape
# Out:
# (18207, 89)

# %%
#changing the name of first column
data.rename(columns={'Unnamed: 0':'S.No.'}, inplace = True)
data.head()
# Out:
#    S.No.      ID               Name  Age  \
# 0      0  158023           L. Messi   31
# 1      1   20801  Cristiano Ronaldo   33
# 2      2  190871          Neymar Jr   26
# 3      3  193080             De Gea   27
# 4      4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# to get the unique countries in the dataset
data.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
#        'Syria', 'Zimbabwe', 'Angola', 'Burkina Faso', 'Iran', 'Estonia',
#        'Tunisia', 'Equatorial Guinea', 'New Zealand', 'FYR Macedonia',
#        'United Arab Emirates', 'China PR', 'Guinea Bissau', 'Bulgaria',
#        'Kosovo', 'South Africa', 'Madagascar', 'Georgia', 'Tanzania',
#        'Gambia', 'Cuba', 'Belarus', 'Uzbekistan', 'Benin', 'Congo',
#        'Mozambique', 'Honduras', 'Canada', 'Northern Ireland', 'Cyprus',
#        'Saudi Arabia', 'Curacao', 'Moldova', 'Bolivia',
#        'Trinidad & Tobago', 'Sierra Leone', 'Zambia', 'Chad',
#        'Philippines', 'Haiti', 'Comoros', 'Libya', 'Panama',
#        'São Tomé & Príncipe', 'Eritrea', 'Oman', 'Iraq', 'Burundi',
#        'Fiji', 'New Caledonia', 'Lithuania', 'Luxembourg', 'Korea DPR',
#        'Liechtenstein', 'St Kitts Nevis', 'Latvia', 'Suriname', 'Uganda',
#        'El Salvador', 'Bermuda', 'Kuwait', 'Antigua & Barbuda',
#        'Thailand', 'Mauritius', 'Guatemala', 'Liberia', 'Kazakhstan',
#        'Niger', 'Mauritania', 'Montserrat', 'Namibia', 'Azerbaijan',
#        'Guam', 'Faroe Islands', 'India', 'Nicaragua', 'Barbados',
#        'Lebanon', 'Palestine', 'Guyana', 'Sudan', 'St Lucia', 'Ethiopia',
#        'Puerto Rico', 'Grenada', 'Jordan', 'Rwanda', 'Qatar',
#        'Afghanistan', 'Hong Kong', 'Andorra', 'Malta', 'Belize',
#        'South Sudan', 'Indonesia', 'Botswana'], dtype=object)

# %%
# to get number the unique countries in the dataset
len(data.Nationality.unique())
# Out:
# 164

# %%
#Average overall performance
data['Overall'].mean()
# Out:
# 66.23869940132916

# %%
#Select the rows where overall is more than average overall
odata = data[data.Overall > 66]
odata
# Out:
#       S.No.      ID               Name  Age  \
# 0         0  158023           L. Messi   31
# 1         1   20801  Cristiano Ronaldo   33
# 2         2  190871          Neymar Jr   26
# 3         3  193080             De Gea   27
# 4         4  192985       K. De Bruyne   27
# ...     ...     ...                ...  ...
# 8759   8759  224509           U. Rivas   22
# 8760   8760  214014        C. Lizarazo   27
# 8761   8761  104702         D. Braaten   36
# 8762   8762  229631               Lazo   22
# 8763   8763  246015            L. Mago   23
#
#                                                Photo Nationality  \
# 0     https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1      https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2     https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3     https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4     https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                              ...         ...
# 8759  https://cdn.sofifa.org/players/4/19/224509.png      Mexico
# 8760  https://cdn.sofifa.org/players/4/19/214014.png    Colombia
# 8761  https://cdn.sofifa.org/players/4/19/104702.png      Norway
# 8762  https://cdn.sofifa.org/players/4/19/229631.png       Spain
# 8763  https://cdn.sofifa.org/players/4/19/246015.png   Venezuela
#
#                                      Flag  Overall  Potential  \
# 0     https://cdn.sofifa.org/flags/52.png       94         94
# 1     https://cdn.sofifa.org/flags/38.png       94         94
# 2     https://cdn.sofifa.org/flags/54.png       92         93
# 3     https://cdn.sofifa.org/flags/45.png       91         93
# 4      https://cdn.sofifa.org/flags/7.png       91         92
# ...                                   ...      ...        ...
# 8759  https://cdn.sofifa.org/flags/83.png       67         73
# 8760  https://cdn.sofifa.org/flags/56.png       67         67
# 8761  https://cdn.sofifa.org/flags/36.png       67         67
# 8762  https://cdn.sofifa.org/flags/45.png       67         75
# 8763  https://cdn.sofifa.org/flags/61.png       67         73
#
#                      Club  ... Composure Marking StandingTackle  \
# 0            FC Barcelona  ...      96.0    33.0           28.0
# 1                Juventus  ...      95.0    28.0           31.0
# 2     Paris Saint-Germain  ...      94.0    27.0           24.0
# 3       Manchester United  ...      68.0    15.0           21.0
# 4         Manchester City  ...      88.0    68.0           58.0
# ...                   ...  ...       ...     ...            ...
# 8759        Santos Laguna  ...      60.0    57.0           66.0
# 8760      América de Cali  ...      63.0    54.0           40.0
# 8761             SK Brann  ...      78.0    45.0           54.0
# 8762              CD Lugo  ...      45.0    45.0           33.0
# 8763                  NaN  ...      52.0    66.0           68.0
#
#       SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 0              26.0      6.0        11.0       15.0           14.0        8.0
# 1              23.0      7.0        11.0       15.0           14.0       11.0
# 2              33.0      9.0         9.0       15.0           15.0       11.0
# 3              13.0     90.0        85.0       87.0           88.0       94.0
# 4              51.0     15.0        13.0        5.0           10.0       13.0
# ...             ...      ...         ...        ...            ...        ...
# 8759           61.0      6.0        15.0       14.0            8.0       13.0
# 8760           28.0     12.0        11.0       13.0            8.0        7.0
# 8761           55.0      9.0        15.0        7.0            8.0       16.0
# 8762           31.0     11.0         7.0        9.0           11.0        6.0
# 8763           67.0     12.0        14.0        9.0            8.0       12.0
#
#      Release Clause
# 0           €226.5M
# 1           €127.1M
# 2           €228.1M
# 3           €138.6M
# 4           €196.4M
# ...             ...
# 8759            €2M
# 8760          €1.1M
# 8761          €325K
# 8762            NaN
# 8763            NaN
#
# [8764 rows x 89 columns]

# %%
#drop image columns
odata.drop(['Photo', 'Flag'], axis=1)
# Out:
#       S.No.      ID               Name  Age Nationality  Overall  Potential  \
# 0         0  158023           L. Messi   31   Argentina       94         94
# 1         1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2         2  190871          Neymar Jr   26      Brazil       92         93
# 3         3  193080             De Gea   27       Spain       91         93
# 4         4  192985       K. De Bruyne   27     Belgium       91         92
# ...     ...     ...                ...  ...         ...      ...        ...
# 8759   8759  224509           U. Rivas   22      Mexico       67         73
# 8760   8760  214014        C. Lizarazo   27    Colombia       67         67
# 8761   8761  104702         D. Braaten   36      Norway       67         67
# 8762   8762  229631               Lazo   22       Spain       67         75
# 8763   8763  246015            L. Mago   23   Venezuela       67         73
#
#                      Club                                        Club Logo  \
# 0            FC Barcelona     https://cdn.sofifa.org/teams/2/light/241.png
# 1                Juventus      https://cdn.sofifa.org/teams/2/light/45.png
# 2     Paris Saint-Germain      https://cdn.sofifa.org/teams/2/light/73.png
# 3       Manchester United      https://cdn.sofifa.org/teams/2/light/11.png
# 4         Manchester City      https://cdn.sofifa.org/teams/2/light/10.png
# ...                   ...                                              ...
# 8759        Santos Laguna  https://cdn.sofifa.org/teams/2/light/110144.png
# 8760      América de Cali  https://cdn.sofifa.org/teams/2/light/101099.png
# 8761             SK Brann     https://cdn.sofifa.org/teams/2/light/919.png
# 8762              CD Lugo  https://cdn.sofifa.org/teams/2/light/110831.png
# 8763                  NaN              https://cdn.sofifa.org/flags/61.png
#
#         Value  ... Composure  Marking StandingTackle  SlidingTackle  GKDiving  \
# 0     €110.5M  ...      96.0     33.0           28.0           26.0       6.0
# 1        €77M  ...      95.0     28.0           31.0           23.0       7.0
# 2     €118.5M  ...      94.0     27.0           24.0           33.0       9.0
# 3        €72M  ...      68.0     15.0           21.0           13.0      90.0
# 4       €102M  ...      88.0     68.0           58.0           51.0      15.0
# ...       ...  ...       ...      ...            ...            ...       ...
# 8759      €1M  ...      60.0     57.0           66.0           61.0       6.0
# 8760    €800K  ...      63.0     54.0           40.0           28.0      12.0
# 8761    €260K  ...      78.0     45.0           54.0           55.0       9.0
# 8762    €1.1M  ...      45.0     45.0           33.0           31.0      11.0
# 8763       €0  ...      52.0     66.0           68.0           67.0      12.0
#
#       GKHandling GKKicking GKPositioning GKReflexes Release Clause
# 0           11.0      15.0          14.0        8.0        €226.5M
# 1           11.0      15.0          14.0       11.0        €127.1M
# 2            9.0      15.0          15.0       11.0        €228.1M
# 3           85.0      87.0          88.0       94.0        €138.6M
# 4           13.0       5.0          10.0       13.0        €196.4M
# ...          ...       ...           ...        ...            ...
# 8759        15.0      14.0           8.0       13.0            €2M
# 8760        11.0      13.0           8.0        7.0          €1.1M
# 8761        15.0       7.0           8.0       16.0          €325K
# 8762         7.0       9.0          11.0        6.0            NaN
# 8763        14.0       9.0           8.0       12.0            NaN
#
# [8764 rows x 87 columns]

# %%
odata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8764 entries, 0 to 8763
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   S.No.                     8764 non-null   int64
#  1   ID                        8764 non-null   int64
#  2   Name                      8764 non-null   object
#  3   Age                       8764 non-null   int64
#  4   Photo                     8764 non-null   object
#  5   Nationality               8764 non-null   object
#  6   Flag                      8764 non-null   object
#  7   Overall                   8764 non-null   int64
#  8   Potential                 8764 non-null   int64
#  9   Club                      8619 non-null   object
#  10  Club Logo                 8764 non-null   object
#  11  Value                     8764 non-null   object
#  12  Wage                      8764 non-null   object
#  13  Special                   8764 non-null   int64
#  14  Preferred Foot            8764 non-null   object
#  15  International Reputation  8764 non-null   float64
#  16  Weak Foot                 8764 non-null   float64
#  17  Skill Moves               8764 non-null   float64
#  18  Work Rate                 8764 non-null   object
#  19  Body Type                 8764 non-null   object
#  20  Real Face                 8764 non-null   object
#  21  Position                  8761 non-null   object
#  22  Jersey Number             8761 non-null   float64
#  23  Joined                    7929 non-null   object
#  24  Loaned From               690 non-null    object
#  25  Contract Valid Until      8619 non-null   object
#  26  Height                    8764 non-null   object
#  27  Weight                    8764 non-null   object
#  28  LS                        7958 non-null   object
#  29  ST                        7958 non-null   object
#  30  RS                        7958 non-null   object
#  31  LW                        7958 non-null   object
#  32  LF                        7958 non-null   object
#  33  CF                        7958 non-null   object
#  34  RF                        7958 non-null   object
#  35  RW                        7958 non-null   object
#  36  LAM                       7958 non-null   object
#  37  CAM                       7958 non-null   object
#  38  RAM                       7958 non-null   object
#  39  LM                        7958 non-null   object
#  40  LCM                       7958 non-null   object
#  41  CM                        7958 non-null   object
#  42  RCM                       7958 non-null   object
#  43  RM                        7958 non-null   object
#  44  LWB                       7958 non-null   object
#  45  LDM                       7958 non-null   object
#  46  CDM                       7958 non-null   object
#  47  RDM                       7958 non-null   object
#  48  RWB                       7958 non-null   object
#  49  LB                        7958 non-null   object
#  50  LCB                       7958 non-null   object
#  51  CB                        7958 non-null   object
#  52  RCB                       7958 non-null   object
#  53  RB                        7958 non-null   object
#  54  Crossing                  8764 non-null   float64
#  55  Finishing                 8764 non-null   float64
#  56  HeadingAccuracy           8764 non-null   float64
#  57  ShortPassing              8764 non-null   float64
#  58  Volleys                   8764 non-null   float64
#  59  Dribbling                 8764 non-null   float64
#  60  Curve                     8764 non-null   float64
#  61  FKAccuracy                8764 non-null   float64
#  62  LongPassing               8764 non-null   float64
#  63  BallControl               8764 non-null   float64
#  64  Acceleration              8764 non-null   float64
#  65  SprintSpeed               8764 non-null   float64
#  66  Agility                   8764 non-null   float64
#  67  Reactions                 8764 non-null   float64
#  68  Balance                   8764 non-null   float64
#  69  ShotPower                 8764 non-null   float64
#  70  Jumping                   8764 non-null   float64
#  71  Stamina                   8764 non-null   float64
#  72  Strength                  8764 non-null   float64
#  73  LongShots                 8764 non-null   float64
#  74  Aggression                8764 non-null   float64
#  75  Interceptions             8764 non-null   float64
#  76  Positioning               8764 non-null   float64
#  77  Vision                    8764 non-null   float64
#  78  Penalties                 8764 non-null   float64
#  79  Composure                 8764 non-null   float64
#  80  Marking                   8764 non-null   float64
#  81  StandingTackle            8764 non-null   float64
#  82  SlidingTackle             8764 non-null   float64
#  83  GKDiving                  8764 non-null   float64
#  84  GKHandling                8764 non-null   float64
#  85  GKKicking                 8764 non-null   float64
#  86  GKPositioning             8764 non-null   float64
#  87  GKReflexes                8764 non-null   float64
#  88  Release Clause            7926 non-null   object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 6.0+ MB
